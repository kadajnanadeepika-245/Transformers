# %%
pip install transformers

# %%
from transformers import pipeline

# %%
q_a=pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# ...

# %%
while True:
    question = input('Enter question (type "exit" to quit): ')
    if question.lower() == 'exit':
        break

    result = q_a(
        question=question,
        context="""
Vignan's Foundation for Science, Technology & Research (VFSTR), also known as Vignan University, is a deemed-to-be university located in Vadlamudi, Guntur, Andhra Pradesh, India.
It was established with the vision of providing high-quality academic programs in engineering and technology.
Vignan University offers undergraduate, postgraduate, and doctoral programs in engineering, science, management, and other disciplines.
The campus is spread over a large area with state-of-the-art infrastructure, including modern classrooms, laboratories, libraries, and sports facilities.
VFSTR has been accredited with an 'A+' grade by NAAC, indicating its commitment to academic excellence.
The university places a strong emphasis on research and innovation and has collaborations with industries and international universities.
It promotes experiential learning through hands-on training, internships, and project-based learning.
Vignan organizes national-level technical and cultural festivals, such as Mahotsav and Vastrotsav, to encourage student participation and showcase talents.
The university has a dedicated placement cell that assists students in securing jobs in reputed companies.
It also emphasizes values-based education, aiming to develop socially responsible and ethical professionals.
Faculty members at VFSTR are highly qualified, and many are involved in funded research projects.
The university follows a choice-based credit system (CBCS), allowing flexibility in course selection.
It has active student clubs and societies for various interests, including robotics, entrepreneurship, coding, music, and literature.
The university offers scholarships and financial aid to meritorious and economically disadvantaged students.
It maintains an eco-friendly campus with initiatives for sustainability and green practices.
Vignan also supports innovation and entrepreneurship through its incubation center.
It has an internal quality assurance cell (IQAC) that continuously monitors academic and administrative performance.
Vignan encourages students to participate in hackathons, competitions, and conferences to enhance their skills.
Hostel facilities are available for both boys and girls, with a focus on comfort, safety, and hygiene.
The university is committed to producing graduates who are not only technically competent but also socially and ethically aware.
"""
    )

    print(result)
# Out:
# Enter question (type "exit" to quit): what it promotes
# {'score': 0.5248700976371765, 'start': 834, 'end': 855, 'answer': 'experiential learning'}
# Enter question (type "exit" to quit): what university follows
# {'score': 0.42124804854393005, 'start': 1315, 'end': 1320, 'answer': 'VFSTR'}
# Enter question (type "exit" to quit): exit
